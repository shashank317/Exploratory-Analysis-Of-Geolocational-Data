# %% [markdown]
# Immporting all the required libraraies

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'ACSETUPSVCPORT': '23210', 'ACSVCPORT': '17532', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\RAVI\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_3584_IRUSZGIYATXAAGFO', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RAVI01', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\RAVI', 'JPY_INTERRUPT_EVENT': '2864', 'LOCALAPPDATA': 'C:\\Users\\RAVI\\AppData\\Local', 'LOGONSERVER': '\\\\RAVI01', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\RAVI\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;c:\\Users\\RAVI\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python39\\Scripts;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 165 Stepping 2, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': 'a502', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'RLSSVCPORT': '22112', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'USERDOMAIN': 'RAVI01', 'USERDOMAIN_ROAMINGPROFILE': 'RAVI01', 'USERNAME': 'RAVI', 'USERPROFILE': 'C:\\Users\\RAVI', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\RAVI\\AppData\\Roaming\\Code\\CachedData\\b3e4e68a0bc097f0ae7907b217c1119af9e03435', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': 'C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '\\\\.\\pipe\\303a7ec516d1ce4ddcb616dca399a466-1.78.2-main-sock', 'VS ...

# %% [markdown]
# Getting data from the provided co-ordinates within the range of 10 km

# %%
#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.320486,76.839752;r=10000&q=bookstore&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/college.csv')
d
# Out:
#                               title  \
# 0                Majidqi Hatim Hawa
# 1           Malikarjuna Book Centre
# 2           Mallikarjun Book Centre
# 3                  Shiv Book Centre
# 4                Lavanya Book Store
# 5        Shri Guru Books Department
# 6                  Joshi Book Stall
# 7                  Career book bank
# 8       Marathi Medical Book Center
# 9          Eswar Xerox & Stationery
# 10  Pana Lamination Special Binding
# 11                   Nava Karnataka
# 12        Paras Medical Book Stores
# 13       Balaji Medical Book Centre
# 14                Ambica Stationers
# 15               Praja Grandra Laya
# 16              Kalamath Book Store
# 17     Rasion Book Depot Government
# 18                Unique Stationers
# 19             Shri Silpa Publicity
#
#                                                    id language  \
# 0   here:pds:place:356xjxn4-14fdb1813df408dc698d03...       en
# 1   here:pds:place:356xjxn4-bab702dc6e1e02acf8adc1...       en
# 2   here:pds:place:356jx7ps-ecc43e91fe380ad7d40366...    en-GB
# 3   here:pds:place:356jx7ps-1e00ba426a9e0f6600996d...    en-GB
# 4   here:pds:place:356xjxn4-b627496b8fb10edcaec0a4...       en
# 5   here:pds:place:356xjxn4-87e0b88a60b10b7cff9341...       en
# 6   here:pds:place:356jx7ps-c368dcd327bb0a6d7b0b26...    en-GB
# 7   here:pds:place:356jx7ps-162ae7d0109607b864f321...       en
# 8   here:pds:place:356jx7ps-d57954f3262e0d36450c8e...    en-GB
# 9   here:pds:place:356xjxn4-efdd53bad535001bd4b753...       en
# 10  here:pds:place:356xjxn4-6f36e0277f8400ed9613e8...       en
# 11  here:pds:place:356tends-af482587c72a424a80c8db...    en-GB
# 12  here:pds:place:356xjxn4-ce1c791d70240462e255cb...       en
# 13  here:pds:place:356jx7ps-d946cf2139780d9b5f53b7...    en-GB
# 14  here:pds:place:356jx7ps-b96168699101055746bd52...    en-GB
# 15  here:pds:place:356xjxn4-82a9a4133e0a0d8fc236c7...       en
# 16  here:pds:place:356xjxn4-61a370809dc8005bc6d5ee...       en
# 17  here:pds:place:356xjxn4-d19ef1b44497064eab22f3...       en
# 18  here:pds:place:356jx7ps-b77d2543454c00b533c2d9...    en-GB
# 19  here:pds:place:356xjxn4-172c71c12dc90c89a0b3ea...       en
#
#                    ontologyId resultType  \
# 0   here:cm:ontology:bookshop      place
# 1   here:cm:ontology:bookshop      place
# 2   here:cm:ontology:bookshop      place
# 3   here:cm:ontology:bookshop      place
# 4   here:cm:ontology:bookshop      place
# 5   here:cm:ontology:bookshop      place
# 6   here:cm:ontology:bookshop      place
# 7   here:cm:ontology:bookshop      place
# 8   here:cm:ontology:bookshop      place
# 9   here:cm:ontology:bookshop      place
# 10  here:cm:ontology:bookshop      place
# 11  here:cm:ontology:bookshop      place
# 12  here:cm:ontology:bookshop      place
# 13  here:cm:ontology:bookshop      place
# 14  here:cm:ontology:bookshop      place
# 15  here:cm:ontology:bookshop      place
# 16  here:cm:ontology:bookshop      place
# 17  here:cm:ontology:bookshop      place
# 18  here:cm:ontology:bookshop      place
# 19  here:cm:ontology:bookshop      place
#
#                                   access  distance  \
# 0   [{'lat': 17.32359, 'lng': 76.83168}]       922
# 1   [{'lat': 17.31566, 'lng': 76.83148}]      1045
# 2   [{'lat': 17.31569, 'lng': 76.83145}]      1045
# 3   [{'lat': 17.31575, 'lng': 76.83138}]      1045
# 4   [{'lat': 17.31606, 'lng': 76.83097}]      1056
# 5   [{'lat': 17.31606, 'lng': 76.83096}]      1057
# 6   [{'lat': 17.31596, 'lng': 76.83109}]      1059
# 7    [{'lat': 17.31611, 'lng': 76.8309}]      1063
# 8   [{'lat': 17.32955, 'lng': 76.84337}]      1093
# 9   [{'lat': 17.31641, 'lng': 76.83052}]      1095
# 10  [{'lat': 17.31714, 'lng': 76.82998}]      1101
# 11  [{'lat': 17.32075, 'lng': 76.82922}]      1105
# 12  [{'lat': 17.32075, 'lng': 76.82923}]      1114
# 13  [{'lat': 17.32061, 'lng': 76.82909}]      1119
# 14  [{'lat': 17.31806, 'lng': 76.82842}]      1219
# 15  [{'lat': 17.33163, 'lng': 76.84052}]      1241
# 16  [{'lat': 17.31939, 'lng': 76.82782}]      1264
# 17  [{'lat': 17.33177, 'lng': 76.83717}]      1285
# 18  [{'lat': 17.31886, 'lng': 76.82748}]      1309
# 19   [{'lat': 17.33216, 'lng': 76.8367}]      1349
#
#                                            categories  \
# 0   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 1   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 2   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 3   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 4   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 5   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 6   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 7   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 8   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 9   [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 10  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 11  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 12  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 13  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 14  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 15  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 16  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 17  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 18  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
# 19  [{'id': '600-6700-0087', 'name': 'Bookstore', ...
#
#                                         address.label address.countryCode  \
# 0   Majidqi Hatim Hawa, Shambhognlli, Kalaburagi 5...                 IND
# 1   Malikarjuna Book Centre, P D A College Road, S...                 IND
# 2   Mallikarjun Book Centre, P D A College Road, S...                 IND
# 3   Shiv Book Centre, P D A College Road, Shambhog...                 IND
# 4   Lavanya Book Store, P D A College Road, Shambh...                 IND
# 5   Shri Guru Books Department, P D A College Road...                 IND
# 6   Joshi Book Stall, P D A College Road, Shambhog...                 IND
# 7   Career book bank, P D A College Road, Shambhog...                 IND
# 8   Marathi Medical Book Center, Sedam Road, Sunde...                 IND
# 9   Eswar Xerox & Stationery, P D A College Road, ...                 IND
# 10  Pana Lamination Special Binding, Shambhognlli,...                 IND
# 11  Nava Karnataka, Main Road, Shambhognlli, Kalab...                 IND
# 12  Paras Medical Book Stores, Old Hospital Main R...                 IND
# 13  Balaji Medical Book Centre, Main Road, Shambho...                 IND
# 14  Ambica Stationers, P D A College Road, Shambho...                 IND
# 15  Praja Grandra Laya, Sunder Nagar, Adarsh Nagar...                 IND
# 16  Kalamath Book Store, Old Hospital Main Road, S...                 IND
# 17  Rasion Book Depot Government, Adarsh Nagar, Ka...                 IND
# 18  Unique Stationers, P D A College Road, Shambho...                 IND
# 19  Shri Silpa Publicity, Adarsh Nagar, Kalaburagi...                 IND
#
#     ... address.state address.county address.city address.district  \
# 0   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 1   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 2   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 3   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 4   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 5   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 6   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 7   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 8   ...     Karnataka     Kalaburagi   Kalaburagi     Adarsh Nagar
# 9   ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 10  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 11  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 12  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 13  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 14  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 15  ...     Karnataka     Kalaburagi   Kalaburagi     Adarsh Nagar
# 16  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 17  ...     Karnataka     Kalaburagi   Kalaburagi     Adarsh Nagar
# 18  ...     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 19  ...     Karnataka     Kalaburagi   Kalaburagi     Adarsh Nagar
#
#    address.postalCode position.lat position.lng          address.street  \
# 0              585106     17.32362     76.83171                     NaN
# 1              585106     17.31554     76.83138      P D A College Road
# 2              585106     17.31554     76.83138      P D A College Road
# 3              585106     17.31554     76.83138      P D A College Road
# 4              585106     17.31605     76.83096      P D A College Road
# 5              585106     17.31605     76.83095      P D A College Road
# 6              585106     17.31570     76.83113      P D A College Road
# 7              585106     17.31608     76.83087      P D A College Road
# 8              585105     17.32968     76.84340              Sedam Road
# 9              585106     17.31629     76.83042      P D A College Road
# 10             585106     17.31723     76.82996                     NaN
# 11             585106     17.32063     76.82934               Main Road
# 12             585106     17.32072     76.82926  Old Hospital Main Road
# 13             585106     17.32050     76.82921               Main Road
# 14             585106     17.31818     76.82852      P D A College Road
# 15             585105     17.33163     76.84052                     NaN
# 16             585106     17.31929     76.82791  Old Hospital Main Road
# 17             585105     17.33176     76.83708                     NaN
# 18             585106     17.31891     76.82753      P D A College Road
# 19             585105     17.33226     76.83667                     NaN
#
#                                            references address.subdistrict
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2   [{'supplier': {'id': 'core'}, 'id': '113612918...                 NaN
# 3   [{'supplier': {'id': 'core'}, 'id': '113612918...                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6   [{'supplier': {'id': 'core'}, 'id': '113612919...                 NaN
# 7   [{'supplier': {'id': 'core'}, 'id': '113612940...                 NaN
# 8   [{'supplier': {'id': 'core'}, 'id': '117900707...        Sunder Nagar
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11  [{'supplier': {'id': 'core'}, 'id': '113612852...                 NaN
# 12                                                NaN                 NaN
# 13  [{'supplier': {'id': 'core'}, 'id': '113612852...                 NaN
# 14  [{'supplier': {'id': 'core'}, 'id': '113612884...                 NaN
# 15                                                NaN        Sunder Nagar
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18  [{'supplier': {'id': 'core'}, 'id': '113612872...                 NaN
# 19                                                NaN                 NaN
#
# [20 rows x 22 columns]

# %% [markdown]
# Now we need to see the availabel data columns first for cleaning of data

# %%
d.columns
# Out:
# Index(['title', 'id', 'language', 'ontologyId', 'resultType', 'access',
#        'distance', 'categories', 'address.label', 'address.countryCode',
#        'address.countryName', 'address.stateCode', 'address.state',
#        'address.county', 'address.city', 'address.district',
#        'address.postalCode', 'position.lat', 'position.lng', 'address.street',
#        'references', 'address.subdistrict'],
#       dtype='object')

# %% [markdown]
# Now we will clean data and keep whichever fields are required

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                               title  \
# 0                Majidqi Hatim Hawa
# 1           Malikarjuna Book Centre
# 2           Mallikarjun Book Centre
# 3                  Shiv Book Centre
# 4                Lavanya Book Store
# 5        Shri Guru Books Department
# 6                  Joshi Book Stall
# 7                  Career book bank
# 8       Marathi Medical Book Center
# 9          Eswar Xerox & Stationery
# 10  Pana Lamination Special Binding
# 11                   Nava Karnataka
# 12        Paras Medical Book Stores
# 13       Balaji Medical Book Centre
# 14                Ambica Stationers
# 15               Praja Grandra Laya
# 16              Kalamath Book Store
# 17     Rasion Book Depot Government
# 18                Unique Stationers
# 19             Shri Silpa Publicity
#
#                                         address.label  distance  \
# 0   Majidqi Hatim Hawa, Shambhognlli, Kalaburagi 5...       922
# 1   Malikarjuna Book Centre, P D A College Road, S...      1045
# 2   Mallikarjun Book Centre, P D A College Road, S...      1045
# 3   Shiv Book Centre, P D A College Road, Shambhog...      1045
# 4   Lavanya Book Store, P D A College Road, Shambh...      1056
# 5   Shri Guru Books Department, P D A College Road...      1057
# 6   Joshi Book Stall, P D A College Road, Shambhog...      1059
# 7   Career book bank, P D A College Road, Shambhog...      1063
# 8   Marathi Medical Book Center, Sedam Road, Sunde...      1093
# 9   Eswar Xerox & Stationery, P D A College Road, ...      1095
# 10  Pana Lamination Special Binding, Shambhognlli,...      1101
# 11  Nava Karnataka, Main Road, Shambhognlli, Kalab...      1105
# 12  Paras Medical Book Stores, Old Hospital Main R...      1114
# 13  Balaji Medical Book Centre, Main Road, Shambho...      1119
# 14  Ambica Stationers, P D A College Road, Shambho...      1219
# 15  Praja Grandra Laya, Sunder Nagar, Adarsh Nagar...      1241
# 16  Kalamath Book Store, Old Hospital Main Road, S...      1264
# 17  Rasion Book Depot Government, Adarsh Nagar, Ka...      1285
# 18  Unique Stationers, P D A College Road, Shambho...      1309
# 19  Shri Silpa Publicity, Adarsh Nagar, Kalaburagi...      1349
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 17.32359, 'lng': 76.83168}]      17.32362      76.83171
# 1   [{'lat': 17.31566, 'lng': 76.83148}]      17.31554      76.83138
# 2   [{'lat': 17.31569, 'lng': 76.83145}]      17.31554      76.83138
# 3   [{'lat': 17.31575, 'lng': 76.83138}]      17.31554      76.83138
# 4   [{'lat': 17.31606, 'lng': 76.83097}]      17.31605      76.83096
# 5   [{'lat': 17.31606, 'lng': 76.83096}]      17.31605      76.83095
# 6   [{'lat': 17.31596, 'lng': 76.83109}]      17.31570      76.83113
# 7    [{'lat': 17.31611, 'lng': 76.8309}]      17.31608      76.83087
# 8   [{'lat': 17.32955, 'lng': 76.84337}]      17.32968      76.84340
# 9   [{'lat': 17.31641, 'lng': 76.83052}]      17.31629      76.83042
# 10  [{'lat': 17.31714, 'lng': 76.82998}]      17.31723      76.82996
# 11  [{'lat': 17.32075, 'lng': 76.82922}]      17.32063      76.82934
# 12  [{'lat': 17.32075, 'lng': 76.82923}]      17.32072      76.82926
# 13  [{'lat': 17.32061, 'lng': 76.82909}]      17.32050      76.82921
# 14  [{'lat': 17.31806, 'lng': 76.82842}]      17.31818      76.82852
# 15  [{'lat': 17.33163, 'lng': 76.84052}]      17.33163      76.84052
# 16  [{'lat': 17.31939, 'lng': 76.82782}]      17.31929      76.82791
# 17  [{'lat': 17.33177, 'lng': 76.83717}]      17.33176      76.83708
# 18  [{'lat': 17.31886, 'lng': 76.82748}]      17.31891      76.82753
# 19   [{'lat': 17.33216, 'lng': 76.8367}]      17.33226      76.83667
#
#    address.postalCode                                                 id
# 0              585106  here:pds:place:356xjxn4-14fdb1813df408dc698d03...
# 1              585106  here:pds:place:356xjxn4-bab702dc6e1e02acf8adc1...
# 2              585106  here:pds:place:356jx7ps-ecc43e91fe380ad7d40366...
# 3              585106  here:pds:place:356jx7ps-1e00ba426a9e0f6600996d...
# 4              585106  here:pds:place:356xjxn4-b627496b8fb10edcaec0a4...
# 5              585106  here:pds:place:356xjxn4-87e0b88a60b10b7cff9341...
# 6              585106  here:pds:place:356jx7ps-c368dcd327bb0a6d7b0b26...
# 7              585106  here:pds:place:356jx7ps-162ae7d0109607b864f321...
# 8              585105  here:pds:place:356jx7ps-d57954f3262e0d36450c8e...
# 9              585106  here:pds:place:356xjxn4-efdd53bad535001bd4b753...
# 10             585106  here:pds:place:356xjxn4-6f36e0277f8400ed9613e8...
# 11             585106  here:pds:place:356tends-af482587c72a424a80c8db...
# 12             585106  here:pds:place:356xjxn4-ce1c791d70240462e255cb...
# 13             585106  here:pds:place:356jx7ps-d946cf2139780d9b5f53b7...
# 14             585106  here:pds:place:356jx7ps-b96168699101055746bd52...
# 15             585105  here:pds:place:356xjxn4-82a9a4133e0a0d8fc236c7...
# 16             585106  here:pds:place:356xjxn4-61a370809dc8005bc6d5ee...
# 17             585105  here:pds:place:356xjxn4-d19ef1b44497064eab22f3...
# 18             585106  here:pds:place:356jx7ps-b77d2543454c00b533c2d9...
# 19             585105  here:pds:place:356xjxn4-172c71c12dc90c89a0b3ea...

# %%
df_final=d2[['position.lat','position.lng']]

bookstoreList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '500040' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
	
    search_query = 'bookstore' #Search for any bookstore
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    bookstoreList.append(venues['title'].count())



df_final['bookstore'] = bookstoreList

df_final
# Out:
#     position.lat  position.lng  bookstore
# 0       17.32362      76.83171         20
# 1       17.31554      76.83138         20
# 2       17.31554      76.83138         20
# 3       17.31554      76.83138         20
# 4       17.31605      76.83096         20
# 5       17.31605      76.83095         20
# 6       17.31570      76.83113         20
# 7       17.31608      76.83087         20
# 8       17.32968      76.84340         20
# 9       17.31629      76.83042         20
# 10      17.31723      76.82996         20
# 11      17.32063      76.82934         20
# 12      17.32072      76.82926         20
# 13      17.32050      76.82921         20
# 14      17.31818      76.82852         20
# 15      17.33163      76.84052         20
# 16      17.31929      76.82791         20
# 17      17.33176      76.83708         20
# 18      17.31891      76.82753         20
# 19      17.33226      76.83667         20

# %%
#Run K-means clustering on dataframe
kclusters = 1

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  bookstore Cluster
# 0       17.32362      76.83171         20       0
# 1       17.31554      76.83138         20       0
# 2       17.31554      76.83138         20       0
# 3       17.31554      76.83138         20       0
# 4       17.31605      76.83096         20       0
# 5       17.31605      76.83095         20       0
# 6       17.31570      76.83113         20       0
# 7       17.31608      76.83087         20       0
# 8       17.32968      76.84340         20       0
# 9       17.31629      76.83042         20       0
# 10      17.31723      76.82996         20       0
# 11      17.32063      76.82934         20       0
# 12      17.32072      76.82926         20       0
# 13      17.32050      76.82921         20       0
# 14      17.31818      76.82852         20       0
# 15      17.33163      76.84052         20       0
# 16      17.31929      76.82791         20       0
# 17      17.33176      76.83708         20       0
# 18      17.31891      76.82753         20       0
# 19      17.33226      76.83667         20       0

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[17.320486,76.839752],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=25,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([17.320486,76.839752],popup='Search place',zoom_start=50).add_to(map_bom)

# %%
#saving the map 
map_bom.save("map/bookstore.html")
