# %% [markdown]
# Immporting all the required libraraies

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'ACSETUPSVCPORT': '23210', 'ACSVCPORT': '17532', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\RAVI\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_12112_AFFNWTBAWKFGQRIA', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RAVI01', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\RAVI', 'JPY_INTERRUPT_EVENT': '1708', 'LOCALAPPDATA': 'C:\\Users\\RAVI\\AppData\\Local', 'LOGONSERVER': '\\\\RAVI01', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\RAVI\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 165 Stepping 2, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': 'a502', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'RLSSVCPORT': '22112', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'USERDOMAIN': 'RAVI01', 'USERDOMAIN_ROAMINGPROFILE': 'RAVI01', 'USERNAME': 'RAVI', 'USERPROFILE': 'C:\\Users\\RAVI', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\RAVI\\AppData\\Roaming\\Code\\CachedData\\e8a3071ea4344d9d48ef8a4df2c097372b0c5161', 'VSCODE_CWD': 'C:\\Users\\RAVI\\Desktop\\project\\New folder (2)\\Exploratory-Analysis-Of-Geolocational-Data-main', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '\\\\.\\pipe\\303a7ec516d1ce4ddcb616dca399a466-1.74.2-main-sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-us","availableLanguage ...

# %% [markdown]
# Getting data from the provided co-ordinates within the range of 10 km

# %%
#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.320486,76.839752;r=10000&q=apartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.320486,76.839752;r=10000&q=gym&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/apartment.csv')
d
# Out:
#                              title  \
# 0      Standard Health and Fitness
# 1                          Aerofit
# 2             V One Fitness Centre
# 3                          Stayfit
# 4           Health Training Center
# 5              Iram Fitness Centre
# 6   Way 2 Health Acoheeday Venture
# 7                   Perfectfitness
# 8          Dantalaya Health Center
# 9             Apple Fitness Center
# 10              Power Gym Gulbarga
# 11                      Golden Gym
# 12                   Six Packs Gym
# 13                            Rock
# 14           Bhavya Fitness Centre
# 15            Modern Body Care Gym
# 16            Shiram Health Centre
# 17                       Atlas Gym
# 18                     Yoga Centre
# 19                    Snap Fitness
#
#                                                    id language  \
# 0   here:pds:place:356jx7ps-3296fd0743c102e494cb57...    en-GB
# 1   here:pds:place:356tends-e4c6d8938ec29c93df26ff...    en-GB
# 2   here:pds:place:356tends-46c362ade0eef159952f9b...    en-GB
# 3   here:pds:place:356jx7ps-f03c316582c50a8c5cf0d5...    en-GB
# 4   here:pds:place:3561r4ve-b9542aab9e5a07e5a04f5a...       en
# 5   here:pds:place:356jx7ps-4a9621b73648017ba39412...    en-GB
# 6   here:pds:place:3561r4ve-06ceacc887780de59a8b79...       en
# 7   here:pds:place:356tends-1f1ea20edee64bca99fc27...       en
# 8   here:pds:place:3561r4ve-b451d4c0b40202f1b2517d...       en
# 9   here:pds:place:356d408k-78e8a4de2b5c0c59ede3e5...       en
# 10  here:pds:place:356tends-f5b5096142ef447c83123d...       en
# 11  here:pds:place:356tends-f1bf71a9bcdcf58a820855...       en
# 12  here:pds:place:356tends-3a1b908d163c45abba09b1...    en-GB
# 13  here:pds:place:356jx7ps-dcd3011bf217076ae14d42...    en-GB
# 14  here:pds:place:356jx7ps-385ba354ce3b0ef7540262...    en-GB
# 15  here:pds:place:356tends-71d59f50a9274b39b5f78f...    en-GB
# 16  here:pds:place:356tends-e8f6c864223a4d79bb17df...       en
# 17  here:pds:place:356jx7ps-008f2a54f5fa0b8b98866a...    en-GB
# 18  here:pds:place:3561r4ve-653ca53502cf04cee1e0eb...       en
# 19  here:pds:place:356tendt-5958cf6b41ec46278a852c...       en
#
#                               ontologyId resultType  \
# 0   here:cm:ontology:fitness_health_club      place
# 1   here:cm:ontology:fitness_health_club      place
# 2   here:cm:ontology:fitness_health_club      place
# 3   here:cm:ontology:fitness_health_club      place
# 4   here:cm:ontology:fitness_health_club      place
# 5   here:cm:ontology:fitness_health_club      place
# 6   here:cm:ontology:fitness_health_club      place
# 7   here:cm:ontology:fitness_health_club      place
# 8   here:cm:ontology:fitness_health_club      place
# 9   here:cm:ontology:fitness_health_club      place
# 10  here:cm:ontology:fitness_health_club      place
# 11  here:cm:ontology:fitness_health_club      place
# 12  here:cm:ontology:fitness_health_club      place
# 13  here:cm:ontology:fitness_health_club      place
# 14  here:cm:ontology:fitness_health_club      place
# 15  here:cm:ontology:fitness_health_club      place
# 16  here:cm:ontology:fitness_health_club      place
# 17  here:cm:ontology:fitness_health_club      place
# 18  here:cm:ontology:fitness_health_club      place
# 19  here:cm:ontology:fitness_health_club      place
#
#                                   access  distance  \
# 0   [{'lat': 17.32206, 'lng': 76.83299}]       756
# 1   [{'lat': 17.32598, 'lng': 76.83431}]       824
# 2   [{'lat': 17.32598, 'lng': 76.83431}]       824
# 3   [{'lat': 17.32598, 'lng': 76.83431}]       824
# 4   [{'lat': 17.32929, 'lng': 76.83613}]      1048
# 5   [{'lat': 17.31673, 'lng': 76.83009}]      1094
# 6   [{'lat': 17.32434, 'lng': 76.82788}]      1312
# 7   [{'lat': 17.33275, 'lng': 76.84031}]      1364
# 8   [{'lat': 17.33331, 'lng': 76.83879}]      1429
# 9    [{'lat': 17.32693, 'lng': 76.8536}]      1638
# 10  [{'lat': 17.32674, 'lng': 76.85444}]      1721
# 11   [{'lat': 17.3363, 'lng': 76.83728}]      1781
# 12  [{'lat': 17.32649, 'lng': 76.85597}]      1847
# 13  [{'lat': 17.32628, 'lng': 76.85629}]      1870
# 14  [{'lat': 17.32607, 'lng': 76.85757}]      1993
# 15    [{'lat': 17.3389, 'lng': 76.8377}]      2058
# 16  [{'lat': 17.33887, 'lng': 76.83591}]      2081
# 17  [{'lat': 17.33913, 'lng': 76.83428}]      2166
# 18  [{'lat': 17.32378, 'lng': 76.86094}]      2281
# 19   [{'lat': 17.3248, 'lng': 76.86231}]      2438
#
#                                            categories  \
# 0   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 1   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 2   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 3   [{'id': '600-6800-0000', 'name': 'Clothing & A...
# 4   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 5   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 6   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 7   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 8   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 9   [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 10  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 11  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 12  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 13  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 14  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 15  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 16  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 17  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 18  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
# 19  [{'id': '800-8600-0191', 'name': 'Fitness/Heal...
#
#                                            references  \
# 0   [{'supplier': {'id': 'core'}, 'id': '113614147...
# 1   [{'supplier': {'id': 'core'}, 'id': '122970855...
# 2   [{'supplier': {'id': 'core'}, 'id': '122970864...
# 3   [{'supplier': {'id': 'core'}, 'id': '113614379...
# 4                                                 NaN
# 5   [{'supplier': {'id': 'core'}, 'id': '113612919...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  [{'supplier': {'id': 'core'}, 'id': '105910471...
# 13  [{'supplier': {'id': 'core'}, 'id': '113612838...
# 14  [{'supplier': {'id': 'core'}, 'id': '113612301...
# 15  [{'supplier': {'id': 'core'}, 'id': '108375768...
# 16                                                NaN
# 17  [{'supplier': {'id': 'core'}, 'id': '113613432...
# 18                                                NaN
# 19                                                NaN
#
#                                         address.label  ... address.district  \
# 0   Standard Health and Fitness, Aiwan E Shahi Roa...  ...     Shambhognlli
# 1   Aerofit, SP Office Road, Rajapur, Kalaburagi 5...  ...          Rajapur
# 2   V One Fitness Centre, SP Office Road, Rajapur,...  ...          Rajapur
# 3   Stayfit, SP Office Road, Rajapur, Kalaburagi 5...  ...          Rajapur
# 4   Health Training Center, Rajapur, Kalaburagi 58...  ...          Rajapur
# 5   Iram Fitness Centre, P D A College Road, Shamb...  ...     Shambhognlli
# 6   Way 2 Health Acoheeday Venture, 1-26-2 Court R...  ...       Bramhapura
# 7   Perfectfitness, Sunder Nagar, Adarsh Nagar, Ka...  ...     Adarsh Nagar
# 8   Dantalaya Health Center, Adarsh Nagar, Kalabur...  ...     Adarsh Nagar
# 9   Apple Fitness Center, Sedam Road, Gubbi Colony...  ...          Badepur
# 10  Power Gym Gulbarga, Sedam Road, Gubbi Colony, ...  ...          Badepur
# 11   Golden Gym, Maktampura, Kalaburagi 585101, India  ...       Maktampura
# 12  Six Packs Gym, Sedam Road, Gubbi Colony, Badep...  ...          Badepur
# 13  Rock, SH-10, Tilak Nagar, Kusnoor, Kalaburagi ...  ...          Kusnoor
# 14  Bhavya Fitness Centre, SH-10, Arihant Nagar-Ve...  ...       KHB Colony
# 15  Modern Body Care Gym, Main Road, Maktampura, K...  ...       Maktampura
# 16  Shiram Health Centre, Vasudev Tower Apartment,...  ...       Bramhapura
# 17  Atlas Gym, S B Temple Road, Halbarga, Bramhapu...  ...       Bramhapura
# 18  Yoga Centre, Tilak Nagar, Kusnoor, Kalaburagi ...  ...          Kusnoor
# 19  Snap Fitness, Sedam Road, Tilak Nagar, Kusnoor...  ...          Kusnoor
#
#         address.street address.postalCode position.lat position.lng  \
# 0   Aiwan E Shahi Road             585106     17.32208     76.83283
# 1       SP Office Road             585106     17.32590     76.83445
# 2       SP Office Road             585106     17.32590     76.83445
# 3       SP Office Road             585106     17.32590     76.83445
# 4                  NaN             585106     17.32927     76.83617
# 5   P D A College Road             585106     17.31683     76.83018
# 6           Court Road             585103     17.32433     76.82806
# 7                  NaN             585105     17.33274     76.84035
# 8                  NaN             585105     17.33331     76.83879
# 9           Sedam Road             585105     17.32697     76.85361
# 10          Sedam Road             585105     17.32694     76.85449
# 11                 NaN             585101     17.33633     76.83729
# 12          Sedam Road             585105     17.32651     76.85597
# 13               SH-10             585106     17.32627     76.85629
# 14               SH-10             585104     17.32610     76.85758
# 15           Main Road             585101     17.33891     76.83786
# 16                 NaN             585101     17.33884     76.83592
# 17     S B Temple Road             585101     17.33924     76.83422
# 18                 NaN             585106     17.32377     76.86096
# 19          Sedam Road             585106     17.32469     76.86229
#
#                                              contacts  \
# 0                                                 NaN
# 1   [{'mobile': [{'value': '+919482335000'}], 'www...
# 2          [{'mobile': [{'value': '+919945954555'}]}]
# 3   [{'mobile': [{'value': '+918722644440'}], 'www...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7           [{'phone': [{'value': '+917026839999'}]}]
# 8                                                 NaN
# 9           [{'phone': [{'value': '+919036315599'}]}]
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14         [{'mobile': [{'value': '+919164125074'}]}]
# 15                                                NaN
# 16                                                NaN
# 17  [{'mobile': [{'value': '+918123457864'}, {'val...
# 18          [{'phone': [{'value': '+919980226664'}]}]
# 19                                                NaN
#
#                     address.subdistrict address.houseNumber  \
# 0                                   NaN                 NaN
# 1                                   NaN                 NaN
# 2                                   NaN                 NaN
# 3                                   NaN                 NaN
# 4                                   NaN                 NaN
# 5                                   NaN                 NaN
# 6                           Anand Nagar              1-26-2
# 7                          Sunder Nagar                 NaN
# 8                                   NaN                 NaN
# 9                          Gubbi Colony                 NaN
# 10                         Gubbi Colony                 NaN
# 11                                  NaN                 NaN
# 12                         Gubbi Colony                 NaN
# 13                          Tilak Nagar                 NaN
# 14  Arihant Nagar-Verendra Patil Layout                 NaN
# 15                                  NaN                 NaN
# 16                             Halbarga                 NaN
# 17                             Halbarga                 NaN
# 18                          Tilak Nagar                 NaN
# 19                          Tilak Nagar                 NaN
#
#            address.building                                     chains
# 0                       NaN                                        NaN
# 1                       NaN                                        NaN
# 2                       NaN                                        NaN
# 3                       NaN                                        NaN
# 4                       NaN                                        NaN
# 5                       NaN                                        NaN
# 6                       NaN                                        NaN
# 7                       NaN                                        NaN
# 8                       NaN                                        NaN
# 9                       NaN                                        NaN
# 10                      NaN                                        NaN
# 11                      NaN                                        NaN
# 12                      NaN                                        NaN
# 13                      NaN                                        NaN
# 14                      NaN                                        NaN
# 15                      NaN                                        NaN
# 16  Vasudev Tower Apartment                                        NaN
# 17                      NaN                                        NaN
# 18                      NaN                                        NaN
# 19                      NaN  [{'id': '23841', 'name': 'Snap Fitness'}]
#
# [20 rows x 26 columns]

# %% [markdown]
# Now we need to see the availabel data columns first for cleaning of data

# %%
d.columns
# Out:
# Index(['title', 'id', 'language', 'ontologyId', 'resultType', 'access',
#        'distance', 'categories', 'references', 'address.label',
#        'address.countryCode', 'address.countryName', 'address.stateCode',
#        'address.state', 'address.county', 'address.city', 'address.district',
#        'address.street', 'address.postalCode', 'position.lat', 'position.lng',
#        'contacts', 'address.subdistrict', 'address.houseNumber',
#        'address.building', 'chains'],
#       dtype='object')

# %% [markdown]
# Now we will clean data and keep whichever fields are required

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','contacts','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                              title  \
# 0      Standard Health and Fitness
# 1                          Aerofit
# 2             V One Fitness Centre
# 3                          Stayfit
# 4           Health Training Center
# 5              Iram Fitness Centre
# 6   Way 2 Health Acoheeday Venture
# 7                   Perfectfitness
# 8          Dantalaya Health Center
# 9             Apple Fitness Center
# 10              Power Gym Gulbarga
# 11                      Golden Gym
# 12                   Six Packs Gym
# 13                            Rock
# 14           Bhavya Fitness Centre
# 15            Modern Body Care Gym
# 16            Shiram Health Centre
# 17                       Atlas Gym
# 18                     Yoga Centre
# 19                    Snap Fitness
#
#                                         address.label  distance  \
# 0   Standard Health and Fitness, Aiwan E Shahi Roa...       756
# 1   Aerofit, SP Office Road, Rajapur, Kalaburagi 5...       824
# 2   V One Fitness Centre, SP Office Road, Rajapur,...       824
# 3   Stayfit, SP Office Road, Rajapur, Kalaburagi 5...       824
# 4   Health Training Center, Rajapur, Kalaburagi 58...      1048
# 5   Iram Fitness Centre, P D A College Road, Shamb...      1094
# 6   Way 2 Health Acoheeday Venture, 1-26-2 Court R...      1312
# 7   Perfectfitness, Sunder Nagar, Adarsh Nagar, Ka...      1364
# 8   Dantalaya Health Center, Adarsh Nagar, Kalabur...      1429
# 9   Apple Fitness Center, Sedam Road, Gubbi Colony...      1638
# 10  Power Gym Gulbarga, Sedam Road, Gubbi Colony, ...      1721
# 11   Golden Gym, Maktampura, Kalaburagi 585101, India      1781
# 12  Six Packs Gym, Sedam Road, Gubbi Colony, Badep...      1847
# 13  Rock, SH-10, Tilak Nagar, Kusnoor, Kalaburagi ...      1870
# 14  Bhavya Fitness Centre, SH-10, Arihant Nagar-Ve...      1993
# 15  Modern Body Care Gym, Main Road, Maktampura, K...      2058
# 16  Shiram Health Centre, Vasudev Tower Apartment,...      2081
# 17  Atlas Gym, S B Temple Road, Halbarga, Bramhapu...      2166
# 18  Yoga Centre, Tilak Nagar, Kusnoor, Kalaburagi ...      2281
# 19  Snap Fitness, Sedam Road, Tilak Nagar, Kusnoor...      2438
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 17.32206, 'lng': 76.83299}]      17.32208      76.83283
# 1   [{'lat': 17.32598, 'lng': 76.83431}]      17.32590      76.83445
# 2   [{'lat': 17.32598, 'lng': 76.83431}]      17.32590      76.83445
# 3   [{'lat': 17.32598, 'lng': 76.83431}]      17.32590      76.83445
# 4   [{'lat': 17.32929, 'lng': 76.83613}]      17.32927      76.83617
# 5   [{'lat': 17.31673, 'lng': 76.83009}]      17.31683      76.83018
# 6   [{'lat': 17.32434, 'lng': 76.82788}]      17.32433      76.82806
# 7   [{'lat': 17.33275, 'lng': 76.84031}]      17.33274      76.84035
# 8   [{'lat': 17.33331, 'lng': 76.83879}]      17.33331      76.83879
# 9    [{'lat': 17.32693, 'lng': 76.8536}]      17.32697      76.85361
# 10  [{'lat': 17.32674, 'lng': 76.85444}]      17.32694      76.85449
# 11   [{'lat': 17.3363, 'lng': 76.83728}]      17.33633      76.83729
# 12  [{'lat': 17.32649, 'lng': 76.85597}]      17.32651      76.85597
# 13  [{'lat': 17.32628, 'lng': 76.85629}]      17.32627      76.85629
# 14  [{'lat': 17.32607, 'lng': 76.85757}]      17.32610      76.85758
# 15    [{'lat': 17.3389, 'lng': 76.8377}]      17.33891      76.83786
# 16  [{'lat': 17.33887, 'lng': 76.83591}]      17.33884      76.83592
# 17  [{'lat': 17.33913, 'lng': 76.83428}]      17.33924      76.83422
# 18  [{'lat': 17.32378, 'lng': 76.86094}]      17.32377      76.86096
# 19   [{'lat': 17.3248, 'lng': 76.86231}]      17.32469      76.86229
#
#    address.postalCode                                           contacts  \
# 0              585106                                                NaN
# 1              585106  [{'mobile': [{'value': '+919482335000'}], 'www...
# 2              585106         [{'mobile': [{'value': '+919945954555'}]}]
# 3              585106  [{'mobile': [{'value': '+918722644440'}], 'www...
# 4              585106                                                NaN
# 5              585106                                                NaN
# 6              585103                                                NaN
# 7              585105          [{'phone': [{'value': '+917026839999'}]}]
# 8              585105                                                NaN
# 9              585105          [{'phone': [{'value': '+919036315599'}]}]
# 10             585105                                                NaN
# 11             585101                                                NaN
# 12             585105                                                NaN
# 13             585106                                                NaN
# 14             585104         [{'mobile': [{'value': '+919164125074'}]}]
# 15             585101                                                NaN
# 16             585101                                                NaN
# 17             585101  [{'mobile': [{'value': '+918123457864'}, {'val...
# 18             585106          [{'phone': [{'value': '+919980226664'}]}]
# 19             585106                                                NaN
#
#                                                    id
# 0   here:pds:place:356jx7ps-3296fd0743c102e494cb57...
# 1   here:pds:place:356tends-e4c6d8938ec29c93df26ff...
# 2   here:pds:place:356tends-46c362ade0eef159952f9b...
# 3   here:pds:place:356jx7ps-f03c316582c50a8c5cf0d5...
# 4   here:pds:place:3561r4ve-b9542aab9e5a07e5a04f5a...
# 5   here:pds:place:356jx7ps-4a9621b73648017ba39412...
# 6   here:pds:place:3561r4ve-06ceacc887780de59a8b79...
# 7   here:pds:place:356tends-1f1ea20edee64bca99fc27...
# 8   here:pds:place:3561r4ve-b451d4c0b40202f1b2517d...
# 9   here:pds:place:356d408k-78e8a4de2b5c0c59ede3e5...
# 10  here:pds:place:356tends-f5b5096142ef447c83123d...
# 11  here:pds:place:356tends-f1bf71a9bcdcf58a820855...
# 12  here:pds:place:356tends-3a1b908d163c45abba09b1...
# 13  here:pds:place:356jx7ps-dcd3011bf217076ae14d42...
# 14  here:pds:place:356jx7ps-385ba354ce3b0ef7540262...
# 15  here:pds:place:356tends-71d59f50a9274b39b5f78f...
# 16  here:pds:place:356tends-e8f6c864223a4d79bb17df...
# 17  here:pds:place:356jx7ps-008f2a54f5fa0b8b98866a...
# 18  here:pds:place:3561r4ve-653ca53502cf04cee1e0eb...
# 19  here:pds:place:356tendt-5958cf6b41ec46278a852c...

# %%
#Counting no. of cafes, department stores and gyms near apartments around IIT Bombay
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '500040' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    CafeList.append(venues['title'].count())
	
    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    GymList.append(venues['title'].count())

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    ResList.append(venues['title'].count())

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList

df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms
# 0       17.32208      76.83283     20           20    20
# 1       17.32590      76.83445     20           20    20
# 2       17.32590      76.83445     20           20    20
# 3       17.32590      76.83445     20           20    20
# 4       17.32927      76.83617     20           20    20
# 5       17.31683      76.83018     20           20    20
# 6       17.32433      76.82806     20           20    20
# 7       17.33274      76.84035     20           20    20
# 8       17.33331      76.83879     20           20    20
# 9       17.32697      76.85361     20           20    20
# 10      17.32694      76.85449     20           20    20
# 11      17.33633      76.83729     20           20    20
# 12      17.32651      76.85597     20           20    20
# 13      17.32627      76.85629     20           20    20
# 14      17.32610      76.85758     20           20    20
# 15      17.33891      76.83786     20           20    20
# 16      17.33884      76.83592     20           20    20
# 17      17.33924      76.83422     20           20    20
# 18      17.32377      76.86096     20           20    20
# 19      17.32469      76.86229     20           20    20

# %%
#Run K-means clustering on dataframe
kclusters = 1

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       17.32208      76.83283     20           20    20       1
# 1       17.32590      76.83445     20           20    20       1
# 2       17.32590      76.83445     20           20    20       1
# 3       17.32590      76.83445     20           20    20       1
# 4       17.32927      76.83617     20           20    20       1
# 5       17.31683      76.83018     20           20    20       1
# 6       17.32433      76.82806     20           20    20       1
# 7       17.33274      76.84035     20           20    20       2
# 8       17.33331      76.83879     20           20    20       2
# 9       17.32697      76.85361     20           20    20       0
# 10      17.32694      76.85449     20           20    20       0
# 11      17.33633      76.83729     20           20    20       2
# 12      17.32651      76.85597     20           20    20       0
# 13      17.32627      76.85629     20           20    20       0
# 14      17.32610      76.85758     20           20    20       0
# 15      17.33891      76.83786     20           20    20       2
# 16      17.33884      76.83592     20           20    20       2
# 17      17.33924      76.83422     20           20    20       2
# 18      17.32377      76.86096     20           20    20       0
# 19      17.32469      76.86229     20           20    20       0

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[17.320486,76.839752],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=25,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([17.320486,76.839752],popup='Search place',zoom_start=50).add_to(map_bom)

# %%
#saving the map 
map_bom.save("apartment.html")
