# %% [markdown]
# Immporting all the required libraraies

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import seaborn as sns
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
import os
os.environ.keys()
# Out:
# KeysView(environ({'ACSETUPSVCPORT': '23210', 'ACSVCPORT': '17532', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\RAVI\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_14184_RZAVQREJUEUUQNWS', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RAVI01', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\RAVI', 'JPY_INTERRUPT_EVENT': '2000', 'LOCALAPPDATA': 'C:\\Users\\RAVI\\AppData\\Local', 'LOGONSERVER': '\\\\RAVI01', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\RAVI\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 165 Stepping 2, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': 'a502', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'RLSSVCPORT': '22112', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'USERDOMAIN': 'RAVI01', 'USERDOMAIN_ROAMINGPROFILE': 'RAVI01', 'USERNAME': 'RAVI', 'USERPROFILE': 'C:\\Users\\RAVI', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\RAVI\\AppData\\Roaming\\Code\\CachedData\\e8a3071ea4344d9d48ef8a4df2c097372b0c5161', 'VSCODE_CWD': 'C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '\\\\.\\pipe\\303a7ec516d1ce4ddcb616dca399a466-1.74.2-main-sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-us","availableLanguages":{},"_languagePackSupport":true}', ' ...

# %% [markdown]
# Getting data from the provided co-ordinates within the range of 10 km

# %%
#Fetching data form HERE API 
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.320486,76.839752;r=10000&q=college&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/college.csv')
d
# Out:
#                                                 title  \
# 0                          Government Nursing College
# 1                           D R S School of Institute
# 2                    Mahadeppe Rampur Medical College
# 3                      Government Independent College
# 4                        College of Teacher Education
# 5   H. K. E Society M. S. I. Arts & Science Degree...
# 6                                    M. S. I. College
# 7                           H K E Polytechnic College
# 8                              Government Polytechnic
# 9               Vijaya Vidyalaya Copm Pre Uni College
# 10                         Pda College of Engineering
# 11               Kottal Basaveshwar Community College
# 12                          D R S School of Institute
# 13                                  Govt. Polytechnic
# 14    H. K. E. Society's P. D. A. Engineering College
# 15                              Ded College Karnataka
# 16                  Government Women's Degree College
# 17                             Vasantha B. Ed College
# 18             Gulbarga Institute of Medical Sciences
# 19        Poojya Doddappa Appa College of Engineering
#
#                                                    id language  \
# 0   here:pds:place:356tends-d7a521068c4b48bfaf4a26...    en-GB
# 1   here:pds:place:356tends-2f2a702229bc4bc0b57d86...    en-GB
# 2   here:pds:place:356tends-27a1e6553fd54c2da243cd...    en-GB
# 3   here:pds:place:356jx7ps-c9a2d1f44a9b01160cac0f...    en-GB
# 4   here:pds:place:356jx7ps-cdd4ec32540f031a32e9cd...    en-GB
# 5   here:pds:place:356tends-aa0b196d52a04aa89bb107...    en-GB
# 6   here:pds:place:356jx7ps-3451860c4af00b27daa982...    en-GB
# 7   here:pds:place:356jx7ps-9880ff53e11200b10d0cec...    en-GB
# 8   here:pds:place:356tends-11d4b260c5634fab964fca...    en-GB
# 9   here:pds:place:356jx7ps-9a1a0e321dc20cf52b2498...    en-GB
# 10  here:pds:place:356tends-04aaf70c02d24c5985fb8e...    en-GB
# 11  here:pds:place:356jx7ps-bd20a21b244503585e3e2d...    en-GB
# 12  here:pds:place:356tends-d0d1dde2e0a44df9b12b01...    en-GB
# 13  here:pds:place:356jx7ps-771c5f567299018972c3ef...    en-GB
# 14  here:pds:place:356tends-fbf8cfe2541d40ad88fd6d...    en-GB
# 15  here:pds:place:356tends-84c08309fa0f44acbb0500...    en-GB
# 16  here:pds:place:356jx7ps-0ab6c97a503c0c3186573f...    en-GB
# 17  here:pds:place:356jx7ps-0632870de09a0766e09531...    en-GB
# 18  here:pds:place:356tends-6b550a869cb94b7bb22f3f...    en-GB
# 19  here:pds:place:356jx7ps-1f825113151d04812743f9...    en-GB
#
#                      ontologyId resultType  \
# 0   here:cm:ontology:university      place
# 1   here:cm:ontology:university      place
# 2   here:cm:ontology:university      place
# 3   here:cm:ontology:university      place
# 4   here:cm:ontology:university      place
# 5   here:cm:ontology:university      place
# 6   here:cm:ontology:university      place
# 7   here:cm:ontology:university      place
# 8   here:cm:ontology:university      place
# 9   here:cm:ontology:university      place
# 10  here:cm:ontology:university      place
# 11  here:cm:ontology:university      place
# 12  here:cm:ontology:university      place
# 13  here:cm:ontology:university      place
# 14  here:cm:ontology:university      place
# 15  here:cm:ontology:university      place
# 16  here:cm:ontology:university      place
# 17  here:cm:ontology:university      place
# 18  here:cm:ontology:university      place
# 19  here:cm:ontology:university      place
#
#                                   access  distance  \
# 0   [{'lat': 17.31923, 'lng': 76.83978}]       140
# 1   [{'lat': 17.31923, 'lng': 76.83978}]       140
# 2   [{'lat': 17.31923, 'lng': 76.83978}]       140
# 3   [{'lat': 17.31736, 'lng': 76.83743}]       441
# 4    [{'lat': 17.3174, 'lng': 76.83649}]       494
# 5   [{'lat': 17.31584, 'lng': 76.83718}]       576
# 6   [{'lat': 17.31539, 'lng': 76.83778}]       590
# 7   [{'lat': 17.31538, 'lng': 76.83778}]       621
# 8   [{'lat': 17.31675, 'lng': 76.83438}]       722
# 9   [{'lat': 17.32054, 'lng': 76.83279}]       722
# 10  [{'lat': 17.31529, 'lng': 76.83462}]       808
# 11  [{'lat': 17.31722, 'lng': 76.83291}]       814
# 12   [{'lat': 17.32263, 'lng': 76.8471}]       816
# 13  [{'lat': 17.31612, 'lng': 76.83297}]       857
# 14   [{'lat': 17.3151, 'lng': 76.83379}]       858
# 15  [{'lat': 17.32836, 'lng': 76.83906}]       885
# 16   [{'lat': 17.32793, 'lng': 76.8361}]       902
# 17  [{'lat': 17.32228, 'lng': 76.84815}]       916
# 18  [{'lat': 17.32712, 'lng': 76.84505}]       923
# 19  [{'lat': 17.31549, 'lng': 76.83285}]       933
#
#                                            categories  \
# 0   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 1   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 2   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 3   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 4   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 5   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 6   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 7   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 8   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 9   [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 10  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 11  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 12  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 13  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 14  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 15  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 16  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 17  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 18  [{'id': '800-8200-0173', 'name': 'Higher Educa...
# 19  [{'id': '800-8200-0173', 'name': 'Higher Educa...
#
#                                            references  \
# 0   [{'supplier': {'id': 'core'}, 'id': '105910329...
# 1   [{'supplier': {'id': 'core'}, 'id': '105910331...
# 2   [{'supplier': {'id': 'core'}, 'id': '105910331...
# 3   [{'supplier': {'id': 'core'}, 'id': '111332973...
# 4   [{'supplier': {'id': 'core'}, 'id': '111332978...
# 5   [{'supplier': {'id': 'core'}, 'id': '120862221...
# 6   [{'supplier': {'id': 'core'}, 'id': '111332973...
# 7   [{'supplier': {'id': 'core'}, 'id': '111332973...
# 8   [{'supplier': {'id': 'core'}, 'id': '104013195...
# 9   [{'supplier': {'id': 'core'}, 'id': '113614147...
# 10  [{'supplier': {'id': 'core'}, 'id': '104013195...
# 11  [{'supplier': {'id': 'core'}, 'id': '113613117...
# 12  [{'supplier': {'id': 'core'}, 'id': '108375620...
# 13  [{'supplier': {'id': 'core'}, 'id': '113613125...
# 14  [{'supplier': {'id': 'core'}, 'id': '120862223...
# 15  [{'supplier': {'id': 'core'}, 'id': '108374982...
# 16  [{'supplier': {'id': 'core'}, 'id': '111332929...
# 17  [{'supplier': {'id': 'core'}, 'id': '113612956...
# 18  [{'supplier': {'id': 'core'}, 'id': '121639900...
# 19  [{'supplier': {'id': 'core'}, 'id': '113613125...
#
#                                         address.label  ... address.stateCode  \
# 0   Government Nursing College, Shambhognlli, Kala...  ...                KA
# 1   D R S School of Institute, Shambhognlli, Kalab...  ...                KA
# 2   Mahadeppe Rampur Medical College, Shambhognlli...  ...                KA
# 3   Government Independent College, Shambhognlli, ...  ...                KA
# 4   College of Teacher Education, Shambhognlli, Ka...  ...                KA
# 5   H. K. E Society M. S. I. Arts & Science Degree...  ...                KA
# 6   M. S. I. College, Shambhognlli, Kalaburagi 585...  ...                KA
# 7   H K E Polytechnic College, Shambhognlli, Kalab...  ...                KA
# 8   Government Polytechnic, Shambhognlli, Kalabura...  ...                KA
# 9   Vijaya Vidyalaya Copm Pre Uni College, Aiwan E...  ...                KA
# 10  Pda College of Engineering, Shambhognlli, Kala...  ...                KA
# 11  Kottal Basaveshwar Community College, Aiwan E ...  ...                KA
# 12  D R S School of Institute, Rajapur, Kalaburagi...  ...                KA
# 13  Govt. Polytechnic, Aiwan E Shahi Road, Shambho...  ...                KA
# 14  H. K. E. Society's P. D. A. Engineering Colleg...  ...                KA
# 15  Ded College Karnataka, S P Office Road, Rajapu...  ...                KA
# 16  Government Women's Degree College, S P Office ...  ...                KA
# 17  Vasantha B. Ed College, Shahabad Road, Rajapur...  ...                KA
# 18  Gulbarga Institute of Medical Sciences, Rajapu...  ...                KA
# 19  Poojya Doddappa Appa College of Engineering, P...  ...                KA
#
#    address.state address.county address.city address.district  \
# 0      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 1      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 2      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 3      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 4      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 5      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 6      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 7      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 8      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 9      Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 10     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 11     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 12     Karnataka     Kalaburagi   Kalaburagi          Rajapur
# 13     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 14     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
# 15     Karnataka     Kalaburagi   Kalaburagi          Rajapur
# 16     Karnataka     Kalaburagi   Kalaburagi          Rajapur
# 17     Karnataka     Kalaburagi   Kalaburagi          Rajapur
# 18     Karnataka     Kalaburagi   Kalaburagi          Rajapur
# 19     Karnataka     Kalaburagi   Kalaburagi     Shambhognlli
#
#    address.postalCode position.lat position.lng      address.street  \
# 0              585106     17.31923     76.83978                 NaN
# 1              585106     17.31923     76.83978                 NaN
# 2              585106     17.31923     76.83978                 NaN
# 3              585106     17.31720     76.83743                 NaN
# 4              585106     17.31730     76.83651                 NaN
# 5              585106     17.31585     76.83733                 NaN
# 6              585106     17.31553     76.83777                 NaN
# 7              585106     17.31523     76.83779                 NaN
# 8              585106     17.31673     76.83421                 NaN
# 9              585106     17.32052     76.83295  Aiwan E Shahi Road
# 10             585106     17.31527     76.83445                 NaN
# 11             585106     17.31722     76.83289  Aiwan E Shahi Road
# 12             585106     17.32263     76.84710                 NaN
# 13             585106     17.31609     76.83312  Aiwan E Shahi Road
# 14             585106     17.31514     76.83393                 NaN
# 15             585106     17.32841     76.83889     S P Office Road
# 16             585106     17.32780     76.83606     S P Office Road
# 17             585106     17.32228     76.84817       Shahabad Road
# 18             585106     17.32718     76.84490                 NaN
# 19             585106     17.31553     76.83266  P D A College Road
#
#                                              contacts
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  [{'phone': [{'value': '+918472291252'}], 'www'...
# 19                                                NaN
#
# [20 rows x 22 columns]

# %% [markdown]
# Now we need to see the availabel data columns first for cleaning of data

# %%
d.columns
# Out:
# Index(['title', 'id', 'language', 'ontologyId', 'resultType', 'access',
#        'distance', 'categories', 'references', 'address.label',
#        'address.countryCode', 'address.countryName', 'address.stateCode',
#        'address.state', 'address.county', 'address.city', 'address.district',
#        'address.postalCode', 'position.lat', 'position.lng', 'address.street',
#        'contacts'],
#       dtype='object')

# %% [markdown]
# Now we will clean data and keep whichever fields are required

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','contacts','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                                                 title  \
# 0                          Government Nursing College
# 1                           D R S School of Institute
# 2                    Mahadeppe Rampur Medical College
# 3                      Government Independent College
# 4                        College of Teacher Education
# 5   H. K. E Society M. S. I. Arts & Science Degree...
# 6                                    M. S. I. College
# 7                           H K E Polytechnic College
# 8                              Government Polytechnic
# 9               Vijaya Vidyalaya Copm Pre Uni College
# 10                         Pda College of Engineering
# 11               Kottal Basaveshwar Community College
# 12                          D R S School of Institute
# 13                                  Govt. Polytechnic
# 14    H. K. E. Society's P. D. A. Engineering College
# 15                              Ded College Karnataka
# 16                  Government Women's Degree College
# 17                             Vasantha B. Ed College
# 18             Gulbarga Institute of Medical Sciences
# 19        Poojya Doddappa Appa College of Engineering
#
#                                         address.label  distance  \
# 0   Government Nursing College, Shambhognlli, Kala...       140
# 1   D R S School of Institute, Shambhognlli, Kalab...       140
# 2   Mahadeppe Rampur Medical College, Shambhognlli...       140
# 3   Government Independent College, Shambhognlli, ...       441
# 4   College of Teacher Education, Shambhognlli, Ka...       494
# 5   H. K. E Society M. S. I. Arts & Science Degree...       576
# 6   M. S. I. College, Shambhognlli, Kalaburagi 585...       590
# 7   H K E Polytechnic College, Shambhognlli, Kalab...       621
# 8   Government Polytechnic, Shambhognlli, Kalabura...       722
# 9   Vijaya Vidyalaya Copm Pre Uni College, Aiwan E...       722
# 10  Pda College of Engineering, Shambhognlli, Kala...       808
# 11  Kottal Basaveshwar Community College, Aiwan E ...       814
# 12  D R S School of Institute, Rajapur, Kalaburagi...       816
# 13  Govt. Polytechnic, Aiwan E Shahi Road, Shambho...       857
# 14  H. K. E. Society's P. D. A. Engineering Colleg...       858
# 15  Ded College Karnataka, S P Office Road, Rajapu...       885
# 16  Government Women's Degree College, S P Office ...       902
# 17  Vasantha B. Ed College, Shahabad Road, Rajapur...       916
# 18  Gulbarga Institute of Medical Sciences, Rajapu...       923
# 19  Poojya Doddappa Appa College of Engineering, P...       933
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 17.31923, 'lng': 76.83978}]      17.31923      76.83978
# 1   [{'lat': 17.31923, 'lng': 76.83978}]      17.31923      76.83978
# 2   [{'lat': 17.31923, 'lng': 76.83978}]      17.31923      76.83978
# 3   [{'lat': 17.31736, 'lng': 76.83743}]      17.31720      76.83743
# 4    [{'lat': 17.3174, 'lng': 76.83649}]      17.31730      76.83651
# 5   [{'lat': 17.31584, 'lng': 76.83718}]      17.31585      76.83733
# 6   [{'lat': 17.31539, 'lng': 76.83778}]      17.31553      76.83777
# 7   [{'lat': 17.31538, 'lng': 76.83778}]      17.31523      76.83779
# 8   [{'lat': 17.31675, 'lng': 76.83438}]      17.31673      76.83421
# 9   [{'lat': 17.32054, 'lng': 76.83279}]      17.32052      76.83295
# 10  [{'lat': 17.31529, 'lng': 76.83462}]      17.31527      76.83445
# 11  [{'lat': 17.31722, 'lng': 76.83291}]      17.31722      76.83289
# 12   [{'lat': 17.32263, 'lng': 76.8471}]      17.32263      76.84710
# 13  [{'lat': 17.31612, 'lng': 76.83297}]      17.31609      76.83312
# 14   [{'lat': 17.3151, 'lng': 76.83379}]      17.31514      76.83393
# 15  [{'lat': 17.32836, 'lng': 76.83906}]      17.32841      76.83889
# 16   [{'lat': 17.32793, 'lng': 76.8361}]      17.32780      76.83606
# 17  [{'lat': 17.32228, 'lng': 76.84815}]      17.32228      76.84817
# 18  [{'lat': 17.32712, 'lng': 76.84505}]      17.32718      76.84490
# 19  [{'lat': 17.31549, 'lng': 76.83285}]      17.31553      76.83266
#
#    address.postalCode                                           contacts  \
# 0              585106                                                NaN
# 1              585106                                                NaN
# 2              585106                                                NaN
# 3              585106                                                NaN
# 4              585106                                                NaN
# 5              585106                                                NaN
# 6              585106                                                NaN
# 7              585106                                                NaN
# 8              585106                                                NaN
# 9              585106                                                NaN
# 10             585106                                                NaN
# 11             585106                                                NaN
# 12             585106                                                NaN
# 13             585106                                                NaN
# 14             585106                                                NaN
# 15             585106                                                NaN
# 16             585106                                                NaN
# 17             585106                                                NaN
# 18             585106  [{'phone': [{'value': '+918472291252'}], 'www'...
# 19             585106                                                NaN
#
#                                                    id
# 0   here:pds:place:356tends-d7a521068c4b48bfaf4a26...
# 1   here:pds:place:356tends-2f2a702229bc4bc0b57d86...
# 2   here:pds:place:356tends-27a1e6553fd54c2da243cd...
# 3   here:pds:place:356jx7ps-c9a2d1f44a9b01160cac0f...
# 4   here:pds:place:356jx7ps-cdd4ec32540f031a32e9cd...
# 5   here:pds:place:356tends-aa0b196d52a04aa89bb107...
# 6   here:pds:place:356jx7ps-3451860c4af00b27daa982...
# 7   here:pds:place:356jx7ps-9880ff53e11200b10d0cec...
# 8   here:pds:place:356tends-11d4b260c5634fab964fca...
# 9   here:pds:place:356jx7ps-9a1a0e321dc20cf52b2498...
# 10  here:pds:place:356tends-04aaf70c02d24c5985fb8e...
# 11  here:pds:place:356jx7ps-bd20a21b244503585e3e2d...
# 12  here:pds:place:356tends-d0d1dde2e0a44df9b12b01...
# 13  here:pds:place:356jx7ps-771c5f567299018972c3ef...
# 14  here:pds:place:356tends-fbf8cfe2541d40ad88fd6d...
# 15  here:pds:place:356tends-84c08309fa0f44acbb0500...
# 16  here:pds:place:356jx7ps-0ab6c97a503c0c3186573f...
# 17  here:pds:place:356jx7ps-0632870de09a0766e09531...
# 18  here:pds:place:356tends-6b550a869cb94b7bb22f3f...
# 19  here:pds:place:356jx7ps-1f825113151d04812743f9...

# %%
x = d2.iloc[:, [2]].values

# %%
kmeans5 = KMeans(n_clusters=5)
y_kmeans5 = kmeans5.fit_predict(x)
print(y_kmeans5)

kmeans5.cluster_centers_
# Out:
# [1 1 1 2 2 3 3 3 0 0 0 0 0 4 4 4 4 4 4 4]
# array([[776.4       ],
#        [140.        ],
#        [467.5       ],
#        [595.66666667],
#        [896.28571429]])

# %%
Error =[]
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i).fit(x)
    kmeans.fit(x)
    Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1,11 ), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10 ))
sns.boxplot(data=d2,ax=ax)
# Out:
# <AxesSubplot: >

# %%
#Counting no. of  department colleges
df_final=d2[['position.lat','position.lng']]

collegeList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '500000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
	
    search_query = 'college' #Search for any college
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    collegeList.append(venues['title'].count())



df_final['college'] = collegeList

df_final
# Out:
#     position.lat  position.lng  college
# 0       17.31923      76.83978       20
# 1       17.31923      76.83978       20
# 2       17.31923      76.83978       20
# 3       17.31720      76.83743       20
# 4       17.31730      76.83651       20
# 5       17.31585      76.83733       20
# 6       17.31553      76.83777       20
# 7       17.31523      76.83779       20
# 8       17.31673      76.83421       20
# 9       17.32052      76.83295       20
# 10      17.31527      76.83445       20
# 11      17.31722      76.83289       20
# 12      17.32263      76.84710       20
# 13      17.31609      76.83312       20
# 14      17.31514      76.83393       20
# 15      17.32841      76.83889       20
# 16      17.32780      76.83606       20
# 17      17.32228      76.84817       20
# 18      17.32718      76.84490       20
# 19      17.31553      76.83266       20

# %%
#Run K-means clustering on dataframe
kclusters = 1

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  college Cluster
# 0       17.31923      76.83978       20       0
# 1       17.31923      76.83978       20       0
# 2       17.31923      76.83978       20       0
# 3       17.31720      76.83743       20       0
# 4       17.31730      76.83651       20       0
# 5       17.31585      76.83733       20       0
# 6       17.31553      76.83777       20       0
# 7       17.31523      76.83779       20       0
# 8       17.31673      76.83421       20       0
# 9       17.32052      76.83295       20       0
# 10      17.31527      76.83445       20       0
# 11      17.31722      76.83289       20       0
# 12      17.32263      76.84710       20       0
# 13      17.31609      76.83312       20       0
# 14      17.31514      76.83393       20       0
# 15      17.32841      76.83889       20       0
# 16      17.32780      76.83606       20       0
# 17      17.32228      76.84817       20       0
# 18      17.32718      76.84490       20       0
# 19      17.31553      76.83266       20       0

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[17.320486,76.839752],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=25,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([17.320486,76.839752],popup='Search place',zoom_start=50).add_to(map_bom)

# %%
#saving the map 
map_bom.save("map/college.html")
