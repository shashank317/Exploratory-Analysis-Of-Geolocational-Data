# %% [markdown]
# Immporting all the required libraraies

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'ACSETUPSVCPORT': '23210', 'ACSVCPORT': '17532', 'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\RAVI\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_12112_AFFNWTBAWKFGQRIA', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'RAVI01', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'ELECTRON_RUN_AS_NODE': '1', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\RAVI', 'JPY_INTERRUPT_EVENT': '3148', 'LOCALAPPDATA': 'C:\\Users\\RAVI\\AppData\\Local', 'LOGONSERVER': '\\\\RAVI01', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\RAVI\\OneDrive', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'OS': 'Windows_NT', 'PATH': 'c:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;;C:\\Users\\RAVI\\Downloads\\Compressed\\bin;C:\\Program Files\\Java\\jdk-16.0.1\\bin;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Windows\\System32\\OpenSSH\\;C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common;C:\\xampp\\mysql\\bin;C:\\Program Files (x86)\\dotnet\\;C:\\Program Files\\dotnet\\;C:\\Program Files\\Process Lasso\\;;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR;C:\\Users\\RAVI\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\RAVI\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 165 Stepping 2, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': 'a502', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules', 'PUBLIC': 'C:\\Users\\Public', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHONIOENCODING': 'utf-8', 'PYTHONUNBUFFERED': '1', 'RLSSVCPORT': '22112', 'SESSIONNAME': 'Console', 'SYSTEMDRIVE': 'C:', 'SYSTEMROOT': 'C:\\WINDOWS', 'TEMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'TMP': 'C:\\Users\\RAVI\\AppData\\Local\\Temp', 'USERDOMAIN': 'RAVI01', 'USERDOMAIN_ROAMINGPROFILE': 'RAVI01', 'USERNAME': 'RAVI', 'USERPROFILE': 'C:\\Users\\RAVI', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\RAVI\\AppData\\Roaming\\Code\\CachedData\\e8a3071ea4344d9d48ef8a4df2c097372b0c5161', 'VSCODE_CWD': 'C:\\Users\\RAVI\\Desktop\\project\\New folder (2)\\Exploratory-Analysis-Of-Geolocational-Data-main', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '\\\\.\\pipe\\303a7ec516d1ce4ddcb616dca399a466-1.74.2-main-sock', 'VSCODE_NLS_CONFIG': '{"locale":"en-us","availableLanguage ...

# %% [markdown]
# Getting data from the provided co-ordinates within the range of 10 km

# %%
#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:17.320486,76.839752;r=10000&q=hostel&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/college.csv')
d
# Out:
#                                                 title  \
# 0                       Government Polytechnic Hostel
# 1                       Government Bed College Hostel
# 2                                   Government Hostel
# 3                            Lamanl Vidyavathi Hostel
# 4                                Asian Mall VG Hostel
# 5                               Al-Badar Girls Hostel
# 6   H. K. E. Societys V. G. Women's Medical Colleg...
# 7                                    Safe Girls House
# 8                                     Ambedkar Hostel
# 9                   Maulana Azad Memorial Boys Hostel
# 10                                   V G Women Hostel
# 11              Smt Veeramma Gangasiri Women's Hostel
# 12                           S M T V G Women's Hostel
# 13                              Madeena Muslim Hostel
# 14                              Al Badar Girls Hostel
# 15                                Inamdar Boys Hostel
# 16                                    Ambedkar Hostel
# 17                              Basaveshwara Hospital
# 18                                      Aisha Complex
# 19                                  Government Hostel
#
#                                                    id language  \
# 0   here:pds:place:356tends-465fb1165dfc45cc82c17b...       en
# 1   here:pds:place:356tends-3dd57a17fb0349049366b4...       en
# 2   here:pds:place:356tends-f0e5e6d9ab2199b8193c3d...       en
# 3   here:pds:place:356tends-aa15d1627e7e4eb68fb685...       en
# 4   here:pds:place:356tends-c2c3bad18fc04708a127f1...       en
# 5   here:pds:place:356tends-639535f6116b4ee10ed866...       en
# 6   here:pds:place:356jx7ps-664ab82e2d27068b6f112e...    en-GB
# 7   here:pds:place:356xjxn4-200fb77ec896079859657f...       en
# 8   here:pds:place:356tends-34de543a4951464da282d1...       en
# 9   here:pds:place:356tendk-ea69f46a1874461d9f2a72...       en
# 10  here:pds:place:356tends-d850339a7b7ce396915371...       en
# 11  here:pds:place:356tends-5d503807f3d34dddb68440...       en
# 12  here:pds:place:356tends-7d92ef23cd5e482eacfd13...       en
# 13  here:pds:place:356jx7ps-a1853ccce01a05b2737aef...    en-GB
# 14  here:pds:place:356tendk-7f5cd784f89bd7aba426f7...       en
# 15  here:pds:place:356tends-d46970c543567feb84ad07...       en
# 16  here:pds:place:356tends-2bd4cea03745434d93d0ae...       en
# 17  here:pds:place:356tends-613e29c4f41bfb4000c2fb...       en
# 18  here:pds:place:356tends-28409ed1561c48a58596b4...       en
# 19  here:pds:place:356xjxn4-4648e6cdd20a05bb9d8546...       en
#
#                  ontologyId resultType                                access  \
# 0   here:cm:ontology:hostel      place  [{'lat': 17.31841, 'lng': 76.83619}]
# 1   here:cm:ontology:hostel      place  [{'lat': 17.31775, 'lng': 76.83619}]
# 2   here:cm:ontology:hostel      place  [{'lat': 17.31568, 'lng': 76.83645}]
# 3   here:cm:ontology:hostel      place  [{'lat': 17.32016, 'lng': 76.83226}]
# 4   here:cm:ontology:hostel      place  [{'lat': 17.32674, 'lng': 76.83487}]
# 5   here:cm:ontology:hostel      place   [{'lat': 17.31852, 'lng': 76.8319}]
# 6   here:cm:ontology:hostel      place  [{'lat': 17.32696, 'lng': 76.83502}]
# 7   here:cm:ontology:hostel      place  [{'lat': 17.32363, 'lng': 76.83162}]
# 8   here:cm:ontology:hostel      place  [{'lat': 17.32435, 'lng': 76.84787}]
# 9   here:cm:ontology:hostel      place  [{'lat': 17.31247, 'lng': 76.83595}]
# 10  here:cm:ontology:hostel      place   [{'lat': 17.3277, 'lng': 76.83442}]
# 11  here:cm:ontology:hostel      place  [{'lat': 17.31861, 'lng': 76.83033}]
# 12  here:cm:ontology:hostel      place  [{'lat': 17.31532, 'lng': 76.83162}]
# 13  here:cm:ontology:hostel      place  [{'lat': 17.32897, 'lng': 76.83433}]
# 14  here:cm:ontology:hostel      place  [{'lat': 17.31325, 'lng': 76.83157}]
# 15  here:cm:ontology:hostel      place  [{'lat': 17.32929, 'lng': 76.84642}]
# 16  here:cm:ontology:hostel      place  [{'lat': 17.32711, 'lng': 76.84916}]
# 17  here:cm:ontology:hostel      place    [{'lat': 17.328, 'lng': 76.84869}]
# 18  here:cm:ontology:hostel      place  [{'lat': 17.33275, 'lng': 76.84031}]
# 19  here:cm:ontology:hostel      place  [{'lat': 17.33246, 'lng': 76.84328}]
#
#     distance                                         categories  \
# 0        470  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 1        514  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 2        630  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 3        793  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 4        826  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 5        838  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 6        861  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 7        930  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 8        949  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 9        974  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 10       982  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 11      1017  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 12      1035  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 13      1100  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 14      1205  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 15      1207  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 16      1255  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 17      1274  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 18      1364  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
# 19      1381  [{'id': '500-5100-0055', 'name': 'Hostel', 'pr...
#
#                                         address.label address.countryCode  \
# 0   Government Polytechnic Hostel, Shambhognlli, K...                 IND
# 1   Government Bed College Hostel, Shambhognlli, K...                 IND
# 2   Government Hostel, Shambhognlli, Kalaburagi 58...                 IND
# 3   Lamanl Vidyavathi Hostel, Shambhognlli, Kalabu...                 IND
# 4   Asian Mall VG Hostel, 117 SP Office Road, Raja...                 IND
# 5   Al-Badar Girls Hostel, Shambhognlli, Kalaburag...                 IND
# 6   H. K. E. Societys V. G. Women's Medical Colleg...                 IND
# 7   Safe Girls House, Shambhognlli, Kalaburagi 585...                 IND
# 8   Ambedkar Hostel, Rajapur, Kalaburagi 585106, I...                 IND
# 9   Maulana Azad Memorial Boys Hostel, Kotnoor D, ...                 IND
# 10  V G Women Hostel, 50, Rajapur, Kalaburagi 5851...                 IND
# 11  Smt Veeramma Gangasiri Women's Hostel, Shambho...                 IND
# 12  S M T V G Women's Hostel, Shambhognlli, Kalabu...                 IND
# 13  Madeena Muslim Hostel, Main Road, Khuba Plots,...                 IND
# 14  Al Badar Girls Hostel, Kotnoor D, Kalaburagi 5...                 IND
# 15  Inamdar Boys Hostel, Adarsh Nagar, Kalaburagi ...                 IND
# 16  Ambedkar Hostel, 12, Rajapur, Kalaburagi 58510...                 IND
# 17  Basaveshwara Hospital, Rajapur, Kalaburagi 585...                 IND
# 18  Aisha Complex, Sunder Nagar, Adarsh Nagar, Kal...                 IND
# 19  Government Hostel, Sunder Nagar, Adarsh Nagar,...                 IND
#
#     ... address.county address.city address.district address.postalCode  \
# 0   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 1   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 2   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 3   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 4   ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 5   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 6   ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 7   ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 8   ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 9   ...     Kalaburagi   Kalaburagi        Kotnoor D             585102
# 10  ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 11  ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 12  ...     Kalaburagi   Kalaburagi     Shambhognlli             585106
# 13  ...     Kalaburagi   Kalaburagi       Bramhapura             585103
# 14  ...     Kalaburagi   Kalaburagi        Kotnoor D             585102
# 15  ...     Kalaburagi   Kalaburagi     Adarsh Nagar             585105
# 16  ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 17  ...     Kalaburagi   Kalaburagi          Rajapur             585106
# 18  ...     Kalaburagi   Kalaburagi     Adarsh Nagar             585105
# 19  ...     Kalaburagi   Kalaburagi     Adarsh Nagar             585105
#
#    position.lat position.lng  address.street  address.houseNumber  \
# 0      17.31842     76.83589             NaN                  NaN
# 1      17.31775     76.83585             NaN                  NaN
# 2      17.31568     76.83662             NaN                  NaN
# 3      17.32051     76.83228             NaN                  NaN
# 4      17.32652     76.83521  SP Office Road                  117
# 5      17.31867     76.83209             NaN                  NaN
# 6      17.32687     76.83515  SP Office Road                  NaN
# 7      17.32366     76.83164             NaN                  NaN
# 8      17.32405     76.84787             NaN                  NaN
# 9      17.31247     76.83606             NaN                  NaN
# 10     17.32772     76.83444             NaN                   50
# 11     17.31865     76.83037             NaN                  NaN
# 12     17.31536     76.83162             NaN                  NaN
# 13     17.32895     76.83438       Main Road                  NaN
# 14     17.31301     76.83154             NaN                  NaN
# 15     17.32928     76.84642             NaN                  NaN
# 16     17.32726     76.84921             NaN                   12
# 17     17.32796     76.84885             NaN                  NaN
# 18     17.33274     76.84035             NaN                  NaN
# 19     17.33244     76.84329             NaN                  NaN
#
#                                            references address.subdistrict
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6   [{'supplier': {'id': 'core'}, 'id': '113614380...                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN                 NaN
# 9                                                 NaN                 NaN
# 10                                                NaN                 NaN
# 11                                                NaN                 NaN
# 12                                                NaN                 NaN
# 13  [{'supplier': {'id': 'core'}, 'id': '113613424...         Khuba Plots
# 14                                                NaN                 NaN
# 15                                                NaN                 NaN
# 16                                                NaN                 NaN
# 17                                                NaN                 NaN
# 18                                                NaN        Sunder Nagar
# 19                                                NaN        Sunder Nagar
#
# [20 rows x 23 columns]

# %% [markdown]
# Now we need to see the availabel data columns first for cleaning of data

# %%
d.columns
# Out:
# Index(['title', 'id', 'language', 'ontologyId', 'resultType', 'access',
#        'distance', 'categories', 'address.label', 'address.countryCode',
#        'address.countryName', 'address.stateCode', 'address.state',
#        'address.county', 'address.city', 'address.district',
#        'address.postalCode', 'position.lat', 'position.lng', 'address.street',
#        'address.houseNumber', 'references', 'address.subdistrict'],
#       dtype='object')

# %% [markdown]
# Now we will clean data and keep whichever fields are required

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                                                 title  \
# 0                       Government Polytechnic Hostel
# 1                       Government Bed College Hostel
# 2                                   Government Hostel
# 3                            Lamanl Vidyavathi Hostel
# 4                                Asian Mall VG Hostel
# 5                               Al-Badar Girls Hostel
# 6   H. K. E. Societys V. G. Women's Medical Colleg...
# 7                                    Safe Girls House
# 8                                     Ambedkar Hostel
# 9                   Maulana Azad Memorial Boys Hostel
# 10                                   V G Women Hostel
# 11              Smt Veeramma Gangasiri Women's Hostel
# 12                           S M T V G Women's Hostel
# 13                              Madeena Muslim Hostel
# 14                              Al Badar Girls Hostel
# 15                                Inamdar Boys Hostel
# 16                                    Ambedkar Hostel
# 17                              Basaveshwara Hospital
# 18                                      Aisha Complex
# 19                                  Government Hostel
#
#                                         address.label  distance  \
# 0   Government Polytechnic Hostel, Shambhognlli, K...       470
# 1   Government Bed College Hostel, Shambhognlli, K...       514
# 2   Government Hostel, Shambhognlli, Kalaburagi 58...       630
# 3   Lamanl Vidyavathi Hostel, Shambhognlli, Kalabu...       793
# 4   Asian Mall VG Hostel, 117 SP Office Road, Raja...       826
# 5   Al-Badar Girls Hostel, Shambhognlli, Kalaburag...       838
# 6   H. K. E. Societys V. G. Women's Medical Colleg...       861
# 7   Safe Girls House, Shambhognlli, Kalaburagi 585...       930
# 8   Ambedkar Hostel, Rajapur, Kalaburagi 585106, I...       949
# 9   Maulana Azad Memorial Boys Hostel, Kotnoor D, ...       974
# 10  V G Women Hostel, 50, Rajapur, Kalaburagi 5851...       982
# 11  Smt Veeramma Gangasiri Women's Hostel, Shambho...      1017
# 12  S M T V G Women's Hostel, Shambhognlli, Kalabu...      1035
# 13  Madeena Muslim Hostel, Main Road, Khuba Plots,...      1100
# 14  Al Badar Girls Hostel, Kotnoor D, Kalaburagi 5...      1205
# 15  Inamdar Boys Hostel, Adarsh Nagar, Kalaburagi ...      1207
# 16  Ambedkar Hostel, 12, Rajapur, Kalaburagi 58510...      1255
# 17  Basaveshwara Hospital, Rajapur, Kalaburagi 585...      1274
# 18  Aisha Complex, Sunder Nagar, Adarsh Nagar, Kal...      1364
# 19  Government Hostel, Sunder Nagar, Adarsh Nagar,...      1381
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 17.31841, 'lng': 76.83619}]      17.31842      76.83589
# 1   [{'lat': 17.31775, 'lng': 76.83619}]      17.31775      76.83585
# 2   [{'lat': 17.31568, 'lng': 76.83645}]      17.31568      76.83662
# 3   [{'lat': 17.32016, 'lng': 76.83226}]      17.32051      76.83228
# 4   [{'lat': 17.32674, 'lng': 76.83487}]      17.32652      76.83521
# 5    [{'lat': 17.31852, 'lng': 76.8319}]      17.31867      76.83209
# 6   [{'lat': 17.32696, 'lng': 76.83502}]      17.32687      76.83515
# 7   [{'lat': 17.32363, 'lng': 76.83162}]      17.32366      76.83164
# 8   [{'lat': 17.32435, 'lng': 76.84787}]      17.32405      76.84787
# 9   [{'lat': 17.31247, 'lng': 76.83595}]      17.31247      76.83606
# 10   [{'lat': 17.3277, 'lng': 76.83442}]      17.32772      76.83444
# 11  [{'lat': 17.31861, 'lng': 76.83033}]      17.31865      76.83037
# 12  [{'lat': 17.31532, 'lng': 76.83162}]      17.31536      76.83162
# 13  [{'lat': 17.32897, 'lng': 76.83433}]      17.32895      76.83438
# 14  [{'lat': 17.31325, 'lng': 76.83157}]      17.31301      76.83154
# 15  [{'lat': 17.32929, 'lng': 76.84642}]      17.32928      76.84642
# 16  [{'lat': 17.32711, 'lng': 76.84916}]      17.32726      76.84921
# 17    [{'lat': 17.328, 'lng': 76.84869}]      17.32796      76.84885
# 18  [{'lat': 17.33275, 'lng': 76.84031}]      17.33274      76.84035
# 19  [{'lat': 17.33246, 'lng': 76.84328}]      17.33244      76.84329
#
#    address.postalCode                                                 id
# 0              585106  here:pds:place:356tends-465fb1165dfc45cc82c17b...
# 1              585106  here:pds:place:356tends-3dd57a17fb0349049366b4...
# 2              585106  here:pds:place:356tends-f0e5e6d9ab2199b8193c3d...
# 3              585106  here:pds:place:356tends-aa15d1627e7e4eb68fb685...
# 4              585106  here:pds:place:356tends-c2c3bad18fc04708a127f1...
# 5              585106  here:pds:place:356tends-639535f6116b4ee10ed866...
# 6              585106  here:pds:place:356jx7ps-664ab82e2d27068b6f112e...
# 7              585106  here:pds:place:356xjxn4-200fb77ec896079859657f...
# 8              585106  here:pds:place:356tends-34de543a4951464da282d1...
# 9              585102  here:pds:place:356tendk-ea69f46a1874461d9f2a72...
# 10             585106  here:pds:place:356tends-d850339a7b7ce396915371...
# 11             585106  here:pds:place:356tends-5d503807f3d34dddb68440...
# 12             585106  here:pds:place:356tends-7d92ef23cd5e482eacfd13...
# 13             585103  here:pds:place:356jx7ps-a1853ccce01a05b2737aef...
# 14             585102  here:pds:place:356tendk-7f5cd784f89bd7aba426f7...
# 15             585105  here:pds:place:356tends-d46970c543567feb84ad07...
# 16             585106  here:pds:place:356tends-2bd4cea03745434d93d0ae...
# 17             585106  here:pds:place:356tends-613e29c4f41bfb4000c2fb...
# 18             585105  here:pds:place:356tends-28409ed1561c48a58596b4...
# 19             585105  here:pds:place:356xjxn4-4648e6cdd20a05bb9d8546...

# %%
#Counting no. of cafes, department stores and hostel near apartments around IIT Bombay
df_final=d2[['position.lat','position.lng']]

hostelList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '500040' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
	
    search_query = 'hostel' #Search for any hostel
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    hostelList.append(venues['title'].count())



df_final['hostel'] = hostelList

df_final
# Out:
#     position.lat  position.lng  hostel
# 0       17.31842      76.83589      20
# 1       17.31775      76.83585      20
# 2       17.31568      76.83662      20
# 3       17.32051      76.83228      20
# 4       17.32652      76.83521      20
# 5       17.31867      76.83209      20
# 6       17.32687      76.83515      20
# 7       17.32366      76.83164      20
# 8       17.32405      76.84787      20
# 9       17.31247      76.83606      20
# 10      17.32772      76.83444      20
# 11      17.31865      76.83037      20
# 12      17.31536      76.83162      20
# 13      17.32895      76.83438      20
# 14      17.31301      76.83154      20
# 15      17.32928      76.84642      20
# 16      17.32726      76.84921      20
# 17      17.32796      76.84885      20
# 18      17.33274      76.84035      20
# 19      17.33244      76.84329      20

# %%
#Run K-means clustering on dataframe
kclusters = 1

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  hostel Cluster
# 0       17.31842      76.83589      20       0
# 1       17.31775      76.83585      20       0
# 2       17.31568      76.83662      20       0
# 3       17.32051      76.83228      20       0
# 4       17.32652      76.83521      20       0
# 5       17.31867      76.83209      20       0
# 6       17.32687      76.83515      20       0
# 7       17.32366      76.83164      20       0
# 8       17.32405      76.84787      20       0
# 9       17.31247      76.83606      20       0
# 10      17.32772      76.83444      20       0
# 11      17.31865      76.83037      20       0
# 12      17.31536      76.83162      20       0
# 13      17.32895      76.83438      20       0
# 14      17.31301      76.83154      20       0
# 15      17.32928      76.84642      20       0
# 16      17.32726      76.84921      20       0
# 17      17.32796      76.84885      20       0
# 18      17.33274      76.84035      20       0
# 19      17.33244      76.84329      20       0

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[17.320486,76.839752],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=25,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([17.320486,76.839752],popup='Search place',zoom_start=50).add_to(map_bom)

# %%
#saving the map 
map_bom.save("map/hostel.html")
